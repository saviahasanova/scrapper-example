# %%
import pandas as pd

df = pd.DataFrame(columns=['title'])

scrapper_kloop = Scrapper('https://kloop.kg', 
                          '/blog/',
                          '//header/@text',
                          df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ac7ac64ccd11> in <module>
#       3 df = pd.DataFrame(columns=['title'])
#       4
# ----> 5 scrapper_kloop = Scrapper('https://kloop.kg', '/blog/',
#       6                           xpath_pattern = '//header/@text',
#       7                          df=df)
#
# NameError: name 'Scrapper' is not defined

# %%
scrapper_kloop.scrape(['https://kloop.kg'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-80bc3c840148> in <module>
# ----> 1 scrapper_kloop.scrape()
#
# NameError: name 'scrapper_kloop' is not defined

# %%
class Scrapper:
    
    def __init__(self, source, link_pattern, xpath, df):
        self.source = source
        self.link_pattern = link_pattern
        self.xpath = xpath
        self.df = df
        self.link_storage = []
        self.link_history = []
    
    def scrape(self, links):
        for link in links:
            seed_page = self.load(link)
            if is_needed():
                self.extract_info(seed_page)
            extract_links(seed_page)
        scrape(link_storage)
